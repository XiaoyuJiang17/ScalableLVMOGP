# %%
import sys
sys.path.append('/Users/jiangxiaoyu/Desktop/All Projects/GPLVM_project_code/')
from util_functions import *
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Load in data

# %%
motion_08_02_path = '/Users/jiangxiaoyu/Desktop/All Projects/GPLVM_project_code/data/CMU_motion_capture/08_02amc.txt'
motion_08_02 = process_motion_capture_data(motion_08_02_path)
num_of_times = motion_08_02.shape[-1]
print(motion_08_02.shape)
# Out:
# (62, 309)

# %% [markdown]
# ## Have a plot

# %%
plt.plot(motion_08_02[55])

# %%
print(motion_08_02)
# Out:
# [[  7.67936    7.70744    7.73681  ...   9.87958    9.8756     9.8679  ]
#  [ 15.39      15.3924    15.3798   ...  16.7236    16.7165    16.723   ]
#  [-38.1799   -37.931    -37.6804   ...  31.4252    31.6317    31.836   ]
#  ...
#  [-15.2402   -16.0521   -17.192    ... -17.6736   -17.5858   -16.6022  ]
#  [  8.58499    9.60223   10.4893   ...  -7.6679    -8.37363   -9.03508 ]
#  [-19.9342   -17.5478   -14.8609   ...   1.8124     1.13542    0.382288]]

# %% [markdown]
# ## reshape and Save data to csv

# %%
path_to_save = '/Users/jiangxiaoyu/Desktop/All Projects/GPLVM_project_code/data/CMU_motion_capture'
pd.DataFrame(motion_08_02.reshape(-1)).to_csv(f'{path_to_save}/08_02.csv', index=False)

# %%
########################    Store the inputs as well      ########################
# evenly distributed between -10 to 10.
input_locs = ( np.array(np.arange(num_of_times)) / num_of_times ) * 20 - 10
pd.DataFrame(input_locs).to_csv(f'{path_to_save}/08_02_inputs.csv', index=False)

# %%
print(input_locs.shape)
# Out:
# (309,)
