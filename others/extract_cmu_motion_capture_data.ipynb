# %%
import sys
sys.path.append('/Users/jiangxiaoyu/Desktop/All Projects/GPLVM_project_code/')
from util_functions import *
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Load in data

# %%
motion_09_11_path = '/Users/jiangxiaoyu/Desktop/All Projects/GPLVM_project_code/data/CMU_motion_capture/09_11amc.txt'
motion_09_11 = process_motion_capture_data(motion_09_11_path, 165)
num_of_times = motion_09_11.shape[-1]
print(motion_09_11.shape)
# Out:
# (62, 165)

# %% [markdown]
# ## Have a plot

# %%
plt.plot(motion_09_11[14])

# %%
print(motion_09_11)
# Out:
# [[  1.30779    1.29888    1.29265  ...   0.347332   0.383829   0.41224 ]
#  [ 18.31      18.2835    18.2477   ...  16.9794    17.0597    17.1526  ]
#  [-31.1539   -30.631    -30.1055   ...  52.4993    52.9718    53.4987  ]
#  ...
#  [  4.42293    3.74717    3.69952  ...  36.0374    34.675     32.9859  ]
#  [ -2.70126   -2.2625    -1.66081  ...  -4.55774   -1.11605    1.54718 ]
#  [-10.7503   -16.2346   -21.6402   ... -10.1189    -7.60811   -5.1937  ]]

# %% [markdown]
# ## reshape and Save data to csv

# %%
path_to_save = '/Users/jiangxiaoyu/Desktop/All Projects/GPLVM_project_code/data/CMU_motion_capture'
pd.DataFrame(motion_09_11.reshape(-1)).to_csv(f'{path_to_save}/09_11.csv', index=False)

# %%
########################    Store the inputs as well      ########################
# evenly distributed between -10 to 10.
input_locs = ( np.array(np.arange(num_of_times)) / num_of_times ) * 20 - 10
pd.DataFrame(input_locs).to_csv(f'{path_to_save}/09_11_inputs.csv', index=False)

# %%
print(input_locs.shape)
# Out:
# (165,)
