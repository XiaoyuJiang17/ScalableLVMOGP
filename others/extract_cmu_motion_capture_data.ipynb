# %%
import sys
sys.path.append('/Users/jiangxiaoyu/Desktop/All Projects/GPLVM_project_code/')
from util_functions import *
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Load in data

# %%
motion_118_03_path = '/Users/jiangxiaoyu/Desktop/All Projects/GPLVM_project_code/data/CMU_motion_capture/118_03amc.txt'
motion_118_03 = process_motion_capture_data(motion_118_03_path, 497)
num_of_times = motion_118_03.shape[-1]
print(motion_118_03.shape)
# Out:
# (62, 497)

# %% [markdown]
# ## Have a plot

# %%
plt.plot(motion_118_03[46])

# %%
print(motion_118_03)
# Out:
# [[  0.173641   0.174942   0.175769 ...   0.193973   0.193956   0.194755]
#  [ 17.5467    17.5462    17.5451   ...  17.3346    17.3339    17.3333  ]
#  [-14.3809   -14.38     -14.3794   ...  -6.4544    -6.4539    -6.45368 ]
#  ...
#  [-10.5095   -10.522    -10.5149   ... -16.0018   -16.0047   -16.0349  ]
#  [  4.29633    4.30122    4.33077  ...   9.18896    9.2113     9.18929 ]
#  [  4.97508    4.99764    4.92262  ...   1.82445    1.84739    1.91714 ]]

# %% [markdown]
# ## reshape and Save data to csv

# %%
path_to_save = '/Users/jiangxiaoyu/Desktop/All Projects/GPLVM_project_code/data/CMU_motion_capture'
pd.DataFrame(motion_118_03.reshape(-1)).to_csv(f'{path_to_save}/118_03.csv', index=False)

# %%
########################    Store the inputs as well      ########################
# evenly distributed between -10 to 10.
'''
input_locs = ( np.array(np.arange(num_of_times)) / num_of_times ) * 20 - 10
pd.DataFrame(input_locs).to_csv(f'{path_to_save}/09_11_inputs.csv', index=False)
'''
# Out:
# "\ninput_locs = ( np.array(np.arange(num_of_times)) / num_of_times ) * 20 - 10\npd.DataFrame(input_locs).to_csv(f'{path_to_save}/09_11_inputs.csv', index=False)\n"

# %%
# print(input_locs.shape)
