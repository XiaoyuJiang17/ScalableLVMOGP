# %%
import sys
sys.path.append('/Users/jiangxiaoyu/Desktop/All Projects/GPLVM_project_code/')
from util_functions import *
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Load in data

# %%
motion_08_09_path = '/Users/jiangxiaoyu/Desktop/All Projects/GPLVM_project_code/data/CMU_motion_capture/08_09amc.txt'
motion_08_09 = process_motion_capture_data(motion_08_09_path, 293)
num_of_times = motion_08_09.shape[-1]
print(motion_08_09.shape)
# Out:
# (62, 293)

# %% [markdown]
# ## Have a plot

# %%
plt.plot(motion_08_09[55])

# %%
print(motion_08_09)
# Out:
# [[  8.6732     8.68865    8.69525  ...   9.68955    9.68397    9.73353 ]
#  [ 15.3502    15.3647    15.3761   ...  16.8157    16.8353    16.9015  ]
#  [-35.602    -35.3272   -35.0724   ...  38.7763    39.0226    39.4707  ]
#  ...
#  [-12.407    -14.9796   -15.1517   ... -18.7257   -18.104    -14.3593  ]
#  [  0.873462   6.70408    2.16423  ...  -8.08644   -8.97745  -10.3748  ]
#  [-13.4933   -30.8176   -18.138    ...  -0.766613   4.55945    6.88464 ]]

# %% [markdown]
# ## reshape and Save data to csv

# %%
path_to_save = '/Users/jiangxiaoyu/Desktop/All Projects/GPLVM_project_code/data/CMU_motion_capture'
pd.DataFrame(motion_08_09.reshape(-1)).to_csv(f'{path_to_save}/08_09.csv', index=False)

# %%
########################    Store the inputs as well      ########################
# evenly distributed between -10 to 10.
input_locs = ( np.array(np.arange(num_of_times)) / num_of_times ) * 20 - 10
pd.DataFrame(input_locs).to_csv(f'{path_to_save}/08_09_inputs.csv', index=False)

# %%
print(input_locs.shape)
# Out:
# (293,)
