# %%
import sys
sys.path.append('/Users/jiangxiaoyu/Desktop/All Projects/GPLVM_project_code/')
from util_functions import *
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Load in data

# %%
motion_118_17_path = '/Users/jiangxiaoyu/Desktop/All Projects/GPLVM_project_code/data/CMU_motion_capture/118_17amc.txt'
motion_118_17 = process_motion_capture_data(motion_118_17_path, 646)
num_of_times = motion_118_17.shape[-1]
print(motion_118_17.shape)
# Out:
# (62, 646)

# %% [markdown]
# ## Have a plot

# %%
plt.plot(motion_118_17[46])

# %%
print(motion_118_17)
# Out:
# [[  0.323782   0.325717   0.327004 ...   0.42085    0.420272   0.420198]
#  [ 17.6159    17.6179    17.6198   ...  17.7401    17.7402    17.74    ]
#  [-13.9946   -13.9863   -13.9786   ...   3.84898    3.84661    3.84373 ]
#  ...
#  [ -9.59538   -9.60234   -9.60003  ...  -9.21502   -9.21018   -9.22791 ]
#  [  7.7588     7.71545    7.69554  ...   9.08074    9.10198    9.09029 ]
#  [ -2.59089   -2.54002   -2.52513  ...   1.61452    1.68207    1.67269 ]]

# %% [markdown]
# ## reshape and Save data to csv

# %%
path_to_save = '/Users/jiangxiaoyu/Desktop/All Projects/GPLVM_project_code/data/CMU_motion_capture'
pd.DataFrame(motion_118_17.reshape(-1)).to_csv(f'{path_to_save}/118_17.csv', index=False)

# %%
########################    Store the inputs as well      ########################
# evenly distributed between -10 to 10.
'''
input_locs = ( np.array(np.arange(num_of_times)) / num_of_times ) * 20 - 10
pd.DataFrame(input_locs).to_csv(f'{path_to_save}/09_11_inputs.csv', index=False)
'''
# Out:
# "\ninput_locs = ( np.array(np.arange(num_of_times)) / num_of_times ) * 20 - 10\npd.DataFrame(input_locs).to_csv(f'{path_to_save}/09_11_inputs.csv', index=False)\n"

# %%
# print(input_locs.shape)
